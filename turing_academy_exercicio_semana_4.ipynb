# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusdavi123/Turing-academy/blob/main/turing_academy_exercicio_semana_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1H3dx5ZkHLbRdiozROfNMUxZQL5-wfDWE" alt="Labels" width="355" height="90">
#
# # Turing Academy 2024 - Exercício Semanal - Semana 4

# %% [markdown]
# Faça um gráfico daora! Pode ser com Matplotlib, Seaborn, Plotly, à sua escolha! Misture diferentes features, personalize os estilos e deixe o gráfico bonito e comunicativo.

# %% [markdown]
# *Para abrir um arquivo um dataset no Colab, você pode fazer upload de um arquivo csv ou ler um arquivo do drive por meio de um link (assim como os notebooks das aulas)*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
url = 'https://raw.githubusercontent.com/matheusdavi123/Turing-academy/main/Pokemon%20(1).csv'
df = pd.read_csv(url)
df.drop_duplicates()
cor_1 = 'lightgray'
cor_2 = 'gold'
labels = ['Comum','Lendário']
plt.figure(figsize = (10,6))
sns.countplot(x='Generation', hue='Legendary', data=df, palette = [cor_1,cor_2])
plt.legend(labels = labels)
plt.title ('Distribuição de Pokémons Lendários e comuns por geração')
plt.xlabel('Geração')
plt.ylabel('Quantia de Pokémons')
plt.show()

# %%
quantia = df.groupby(['Generation'])['Generation'].count()
quantia_acumulada = []
soma = 0
for numero in quantia:
  soma = soma + numero
  quantia_acumulada = quantia_acumulada + [soma]
quantia_acumulada
# Out:
# [166, 272, 432, 553, 718, 800]

# %%
geracao_quantia = np.arange(1,7)
sns.lineplot(x = geracao_quantia, y = quantia_acumulada, color = 'red')
plt.xlabel('geração')
plt.ylabel('Quantia total de Pokémons')
plt.title('Evolução da quantia total de Pokémons ao decorrer das gerações')
# Out:
# Text(0.5, 1.0, 'Evolução da quantia total de Pokémons ao decorrer das gerações')

# %%
plt.figure(figsize = (15,6))
cores = ['darkgreen', 'red', 'blue', 'lightgreen','gray','purple','lightyellow','brown','lightpink','darkred','purple','brown','darkgray','lightblue','darkblue','black','lightgray','gold']
sns.countplot( x =  'Type 1', hue = 'Type 1', data = df, palette = cores)
plt.xlabel('tipo principal')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.figure(figsize = (15,6))
cores = ['darkgreen', 'red', 'blue', 'lightgreen','gray','purple','lightyellow','brown','lightpink','darkred','purple','brown','darkgray','lightblue','darkblue','black','lightgray','gold']
sns.countplot( x = 'Type 2',  hue = 'Type 2' , data = df, palette = cores, legend = None)
plt.xlabel('tipo secundário')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df2 = df.sort_values('Total', ascending = False)
df2 = df2[df2['Legendary'] != True]
df2 = df2.rename(columns = {df.columns[0] : 'numero_pokedex'})
